# %%
import os, shutil
import numpy as np
import matplotlib.pyplot as plt
from facemap.pose import pose
from glob import glob

# %%
filepath = r"C:\Users\Data Analysis\Desktop\mouse975826_Day01_face_comp.avi"

# %%
model = pose.Pose(filenames=[filepath])



model.run()
# Out:
# cuda set as device
# Loading model parameters from: C:\Users\Data Analysis\.facemap\models\facemap_model_params.pth
# Setting model name to: facemap_model_state
# Loading model state from: C:\Users\Data Analysis\.facemap\models\facemap_model_state.pt
#
# Processing video: C
# Using params:
# 	bbox: [0, 0, 0, 0]
# 	batch size: 1
# 	resize: True
# 	padding: False
# Inference speed: nan fps
# Saved keypoints: C_FacemapPose.h5
# Saved metadata: C_FacemapPose_metadata.pkl
#
# Processing video: :
# Using params:
# 	bbox: [0, 0, 0, 0]
# 	batch size: 1
# 	resize: True
# 	padding: False
# Inference speed: nan fps
# Saved keypoints: :_FacemapPose.h5
# Saved metadata: :_FacemapPose_metadata.pkl
#
# Processing video: \
# Using params:
# 	bbox: [0, 0, 0, 0]
# 	batch size: 1
# 	resize: True
# 	padding: False
# Inference speed: nan fps
# Saved keypoints: \_FacemapPose.h5
# Saved metadata: \_FacemapPose_metadata.pkl
#
# Processing video: U
# Using params:
# 	bbox: [0, 0, 0, 0]
# 	batch size: 1
# ...
